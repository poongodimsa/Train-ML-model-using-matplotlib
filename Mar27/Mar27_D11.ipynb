# %% [markdown]
# # Dialogue 11
#
# Author: Poongodi P

# %%
#Initial cell
# %matplotlib inline
import pylab as plt
import numpy as np

# make data
manufacturer = ['BMW', 'VolksWagon', 'TATA', 'Frrari', 'Jaguar']
cylinder = [8,4,16,12,6]
MPG = [21,28,16,12,10]
gears = [8,5,6,7,8]

# %%
#plot a horizontal bar graph of gears for all manufacturers

# %%
fig, ax = plt.subplots()
plt.barh(manufacturer, gears)
# Out:
# <BarContainer object of 5 artists>

# %%
#Add MPG to the chart

# %%
fig, ax = plt.subplots()
plt.barh(manufacturer, gears)
plt.plot(MPG,manufacturer)

# %%
#make gears as yellow coloured bars

# %%
fig, ax = plt.subplots()
plt.barh(manufacturer, gears, color = 'y')
plt.plot(MPG,manufacturer)
