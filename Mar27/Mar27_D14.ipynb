# %% [markdown]
# # Dialogue 13
#
# Author: Poongodi P

# %%
#Initial cell
# %matplotlib inline
import pylab as plt
import numpy as np

# make data
x = 0.15 + np.arange(50) 
z = np.random.normal(1,15, len(x))

# %%
#make subplots with 2 rows and a single column

# %%
fig, axs = plt.subplots(2,1)

# %%
#plot histogram of z in first and plot z as function of x in second

# %%
fig, axs = plt.subplots(2,1)
axs[0].hist(z)
axs[1].plot(z)

# %%
#can you increase the height of the plot?

# %%
fig, axs = plt.subplots(2,1,figsize=(5,10))
axs[0].hist(z)
axs[1].plot(z)
