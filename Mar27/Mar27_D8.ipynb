# %% [markdown]
# # Dialogue 8
#
# Author: Poongodi P

# %%
#Initial cell
# %matplotlib inline
import pylab as plt
import numpy as np

# make data
x = 0.15 + np.arange(50) 
y = np.random.uniform(1,15, len(x))

# %%
#plot y as a function of x

# %%
fig, ax = plt.subplots()
plt.plot(x,y)

# %%
#make the line as red coloured dashes

# %%
fig, ax = plt.subplots()
plt.plot(x,y,'r--')

# %%
#please change dashes to triangles

# %%
fig, ax = plt.subplots()
plt.plot(x,y,'r^')
