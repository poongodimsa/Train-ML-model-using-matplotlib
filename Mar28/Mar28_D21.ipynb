# %% [markdown]
# # Dialogue 21
#
# Author: Poongodi P

# %%
#Initial cell
# %matplotlib inline
import pylab as plt
import numpy as np

# make data
t = np.arange(1,25,1) 
t2 = t**2
t3 = t**3

# %%
# Plot t

# %%
fig, ax = plt.subplots()
plt.plot(t,t)

# %%
#plot t2 and t3 as function of t

# %%
fig, ax = plt.subplots()
plt.plot(t,t)
plt.plot(t,t2)
plt.plot(t,t3)

# %%
#make t2 with 'squares' and t3 with 'triangles'

# %%
fig, ax = plt.subplots()
plt.plot(t,t)
plt.plot(t,t2,'s')
plt.plot(t,t3,'^')
