# %% [markdown]
# # Dialogue 17
#
# Author: Poongodi P

# %%
#Initial cell
# %matplotlib inline
import pylab as plt
import numpy as np

# make data
x = np.arange(.1,10,.01)
s = 1 + np.sin(2 * np.pi * x)
c = 1 + np.cos(2 * np.pi * x)
xtck = np.arange(0.1,1.1,.1)

# %%
#draw a scatter plot of s vs c

# %%
fig, ax = plt.subplots()
plt.scatter(s,c)

# %%
#make it as line plot instead

# %%
fig, ax = plt.subplots()
plt.plot(s,c)

# %%
#Add a title 'Sine and Cosine'

# %%
fig, ax = plt.subplots()
plt.plot(s,c)
ax.set_title('Sine and Cosine')
# Out:
# Text(0.5, 1.0, 'Sine and Cosine')
