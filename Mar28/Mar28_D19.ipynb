# %% [markdown]
# # Dialogue 19
#
# Author: Poongodi P

# %%
#Initial cell
# %matplotlib inline
import pylab as plt
import numpy as np

# make data
binom = np.random.binomial(100,.5,100)
norm = np.random.normal(100,size = 100)

x = np.arange(1,50,2)
y1 = x + np.sin(x)
y2 = 2*x + np.cos(x)

# %%
# Plot y1 and y2 as function of x

# %%
fig, ax = plt.subplots()
plt.plot(x,y1)
plt.plot(x,y2)

# %%
#please fill the area between y1 and y2

# %%
fig, ax = plt.subplots()
plt.fill_between(x,y1,y2)

# %%
#make it transparent

# %%
fig, ax = plt.subplots()
plt.fill_between(x, y1, y2, alpha = 0.2)
