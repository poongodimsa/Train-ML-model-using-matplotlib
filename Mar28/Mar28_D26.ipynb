# %% [markdown]
# # Dialogue 26
#
# Author: Poongodi P

# %%
#Initial cell
# %matplotlib inline
import pylab as plt
import numpy as np
import matplotlib.patches as patches

# make data
x = np.arange(1,50,2)
y =  np.sin(x)

# %%
# Draw a connected scatter plot of x vs y

# %%
fig, ax = plt.subplots()
plt.plot(x,y,linestyle = '-', marker='o')

# %%
#please change the color

# %%
fig, ax = plt.subplots()
plt.plot(x,y,linestyle = '-', marker='o', color = 'mediumvioletred')

# %%
#now chage the marker style to 'x'

# %%
fig, ax = plt.subplots()
plt.plot(x,y,linestyle = '-', marker='x', color = 'mediumvioletred')
