# %% [markdown]
# # Dialogue 106
#
# Author: Poongodi P

# %%
#initial cell
# %matplotlib inline
import numpy as np
import pylab as plt
import matplotlib
import random

#make data
x= np.array(range(0,7))
y = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])

# %%
#plot the array y against x

# %%
fig,ax = plt.subplots()
for i, array in enumerate(y):
    plt.plot(x, array, color = np.random.rand(3, ), marker = "o")

# %%
#change the marker to square

# %%
fig,ax = plt.subplots()
for i, array in enumerate(y):
    plt.plot(x, array, color = np.random.rand(3, ), marker = "s")

# %%
#show the grid lines

# %%
fig,ax = plt.subplots()
for i, array in enumerate(y):
    plt.plot(x, array, color = np.random.rand(3, ), marker = "s")
ax.grid()
