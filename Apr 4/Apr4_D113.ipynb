# %% [markdown]
# # Dialogue 113
#
# Author: Poongodi P

# %%
#initial cell
# %matplotlib inline
import numpy as np
import pylab as plt

# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)
z = np.random.rand(10)

# %%
#plot a stem chart of y vs x

# %%
fig,ax = plt.subplots()
ax.stem(x,y)
# Out:
# <StemContainer object of 3 artists>

# %%
#change the stem head to triangle

# %%
fig,ax = plt.subplots()
ax.stem(x,y,markerfmt = '^')
# Out:
# <StemContainer object of 3 artists>

# %%
#make the lines 'dotted'

# %%
fig,ax = plt.subplots()
ax.stem(x,y,markerfmt = '^', linefmt = ':')
# Out:
# <StemContainer object of 3 artists>
