# %% [markdown]
# # AI chatbot Trainer - Mar26 - Dialogue 1
#
# Author: Poongodi P

# %%
# %matplotlib inline
import pylab as plt
import numpy as np

model = ['VW','BZ','SZ','TA','BM']
price  = [1200,3400,2000,5890,4789]
MPG = [21,14,16,18,12]

# %%
#Plot model vs price

# %%
fig, ax = plt.subplots()
plt.plot(model, price, label = 'Price')

# %%
#Increment y in the interval of 500

# %%
fig, ax = plt.subplots()
tck = np.arange(500,7000,500)
ax.set_yticks (tck)
plt.plot(model, price)

# %%
#Please make the line red

# %%
fig, ax = plt.subplots()
tck = np.arange(500,7000,500)
ax.set_yticks (tck)
plt.plot(model, price, color='r')
