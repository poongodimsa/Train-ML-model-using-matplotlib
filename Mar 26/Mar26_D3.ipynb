# %% [markdown]
# # Dialogue 3
#
# Author: Poongodi P

# %%
#Initial cell
# %matplotlib inline
import pylab as plt
import numpy as np

model = ['VW','BZ','SZ','TA','BM']
price  = [1200,3400,2000,5890,4789]
price.sort()
MPG = [21,14,18,10,11]
price_mean = np.mean(price)

# %%
#Show how price relates to MPG

# %%
fig, ax = plt.subplots()
plt.plot(MPG, price)
plt.xlabel('MPG')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
#Add a horizontal line at mean of price

# %%
fig, ax = plt.subplots()
plt.plot(MPG, price)
plt.xlabel('MPG')
plt.ylabel('Price')
plt.axhline(price_mean)

# %%
#make the line red

# %%
fig, ax = plt.subplots()
plt.plot(MPG, price)
plt.xlabel('MPG')
plt.ylabel('Price')
plt.axhline(price_mean,color = 'r')
