# %% [markdown]
# # Dialogue 2
#
# Author: Poongodi P

# %%
#Initial cell
# %matplotlib inline
import pylab as plt
import numpy as np

model = ['VW','BZ','SZ','TA','BM']
price  = [1200,3400,2000,5890,4789]
MPG = [21,14,16,18,12]

# %%
#Draw a piechart showing price

# %%
fig, ax = plt.subplots()
plt.pie( price)
# Out:
# ([<matplotlib.patches.Wedge at 0x20bc67763d0>,
# ...
#  [Text(1.073922601558225, 0.23809713535112983, ''),
#   Text(0.5429994120688513, 0.9566355829117388, ''),
#   Text(-0.49379496990984695, 0.9829377028539161, ''),
#   Text(-1.0409071410546742, -0.35568570916102976, ''),
#   Text(0.7087078500589972, -0.8412687937067167, '')])

# %%
#Make the circle bigger

# %%
fig, ax = plt.subplots()
plt.pie( price, radius = 2)
# Out:
# ([<matplotlib.patches.Wedge at 0x20bc6b7a520>,
# ...
#  [Text(2.14784520311645, 0.47619427070225967, ''),
#   Text(1.0859988241377025, 1.9132711658234776, ''),
#   Text(-0.9875899398196939, 1.9658754057078323, ''),
#   Text(-2.0818142821093484, -0.7113714183220595, ''),
#   Text(1.4174157001179943, -1.6825375874134334, '')])

# %%
#Shall I have the chart in blues?

# %%
fig, ax = plt.subplots()
color = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(price)))
plt.pie( price, radius = 2, colors = color)
# Out:
# ([<matplotlib.patches.Wedge at 0x20bc66c8c10>,
# ...
#  [Text(2.14784520311645, 0.47619427070225967, ''),
#   Text(1.0859988241377025, 1.9132711658234776, ''),
#   Text(-0.9875899398196939, 1.9658754057078323, ''),
#   Text(-2.0818142821093484, -0.7113714183220595, ''),
#   Text(1.4174157001179943, -1.6825375874134334, '')])
